# %% [markdown]
# <a href="https://colab.research.google.com/github/andreacortesccv2017-boop/taller-mineria-de-datos-/blob/main/taller_mineria_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importacion de librerias necesarias
import pandas as pd

# %%
# Extraccion de los datos
tabla_datos = pd.read_csv("/content/teen_phone_addiction_dataset.csv")

# %%
tabla_datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      3000 non-null   int64
#  1   Name                    3000 non-null   object
#  2   Age                     3000 non-null   int64
#  3   Gender                  3000 non-null   object
#  4   Location                3000 non-null   object
#  5   School_Grade            3000 non-null   object
#  6   Daily_Usage_Hours       3000 non-null   float64
#  7   Sleep_Hours             3000 non-null   float64
#  8   Academic_Performance    3000 non-null   int64
#  9   Social_Interactions     3000 non-null   int64
#  10  Exercise_Hours          3000 non-null   float64
#  11  Anxiety_Level           3000 non-null   int64
#  12  Depression_Level        3000 non-null   int64
#  13  Self_Esteem             3000 non-null   int64
# ...

# %%
tabla_datos.head()
# Out:
#    ID               Name  Age  Gender          Location School_Grade  \
# 0   1    Shannon Francis   13  Female        Hansonfort          9th
# 1   2    Scott Rodriguez   17  Female      Theodorefort          7th
# 2   3        Adrian Knox   13   Other       Lindseystad         11th
# 3   4  Brittany Hamilton   18  Female      West Anthony         12th
# 4   5       Steven Smith   14   Other  Port Lindsaystad          9th
#
#    Daily_Usage_Hours  Sleep_Hours  Academic_Performance  Social_Interactions  \
# 0                4.0          6.1                    78                    5
# 1                5.5          6.5                    70                    5
# 2                5.8          5.5                    93                    8
# 3                3.1          3.9                    78                    8
# 4                2.5          6.7                    56                    4
#
#    ...  Screen_Time_Before_Bed  Phone_Checks_Per_Day  Apps_Used_Daily  \
# ...

# %%
tabla_mod = tabla_datos[['Phone_Checks_Per_Day','Phone_Usage_Purpose','Addiction_Level']]
tabla_mod.head()
# Out:
#    Phone_Checks_Per_Day Phone_Usage_Purpose  Addiction_Level
# 0                    86            Browsing             10.0
# 1                    96            Browsing             10.0
# 2                   137           Education              9.2
# 3                   128        Social Media              9.8
# 4                    96              Gaming              8.6
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Phone_Checks_Per_Day'].plot(kind='hist', bins=20, title='Phone_Checks_Per_Day')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Addiction_Level'].plot(kind='hist', bins=20, title='Addiction_Level')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(_df_7['Phone_Usage_Purpose'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(_df_7, x='Addiction_Level', y='Phone_Usage_Purpose', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# /tmp/ipython-input-1580477932.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(_df_7, x='Addiction_Level', y='Phone_Usage_Purpose', inner='stick', palette='Dark2')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(_df_6['Phone_Usage_Purpose'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(_df_6, x='Phone_Checks_Per_Day', y='Phone_Usage_Purpose', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# /tmp/ipython-input-2531946091.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(_df_6, x='Phone_Checks_Per_Day', y='Phone_Usage_Purpose', inner='stick', palette='Dark2')

# %%
from matplotlib import pyplot as plt
_df_3.plot(kind='scatter', x='Phone_Checks_Per_Day', y='Addiction_Level', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_2.groupby('Phone_Usage_Purpose').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt

tabla_datos = tabla_datos["Phone_Usage_Purpose"].value_counts().values
tabla_mod = tabla_mod["Phone_Usage_Purpose"].value_counts().index
plt.figure(figsize=(6,6))
plt.pie(tabla_datos, labels=tabla_mod, autopct='%1.1f%%', startangle=90)
plt.title("Distribución de Propósitos de Uso del Teléfono")
plt.axis('equal')
plt.show()
